# %% [markdown]
# # Computer simulations course 2018/2019-2 @ ELTE
# # Assignment 1: Harmonic Oscillator
# ## 02.12.2019

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_style(style='whitegrid')

# %%
omega = 0.8
x_0 = 0
v_0 = 5
t = 10
dt = 100

# %%
#                    omega  x_0  v_0  t   dt
! ..\Release\sho.exe 0.8     0    5   10  100
# Out:
# Period = 1	t = 7.85398	x = 0.0064657	v = 5.00016	energy = 12.5008
# Period = 2	t = 15.708	x = 0.0129314	v = 5.00031	energy = 12.5016
# Period = 3	t = 23.5619	x = 0.0193971	v = 5.00046	energy = 12.5024
# Period = 4	t = 31.4159	x = 0.0258627	v = 5.00061	energy = 12.5033
# Period = 5	t = 39.2699	x = 0.0323284	v = 5.00075	energy = 12.5041
# Period = 6	t = 47.1239	x = 0.038794	v = 5.00088	energy = 12.5049
# Period = 7	t = 54.9779	x = 0.0452595	v = 5.00101	energy = 12.5057
# Period = 8	t = 62.8319	x = 0.051725	v = 5.00113	energy = 12.5065
# Period = 9	t = 70.6858	x = 0.0581905	v = 5.00125	energy = 12.5073
# Period = 10	t = 78.5398	x = 0.0646559	v = 5.00136	energy = 12.5081

# %%
#data_small = np.genfromtxt('sho.dat')
#data_big = np.genfromtxt('sho.dat')

# %%
steps = 1

# %%
nrows = 2
ncols = 1
fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(ncols*14, nrows*7))

axes[0].plot(data[::steps,0], data[::steps,1], color='grey')
axes[1].plot(data[::steps,0], data[::steps,2], color='grey')

axes[0].scatter(data[::steps,0], data[::steps,1], color='red')
axes[1].scatter(data[::steps,0], data[::steps,2], color='green')

axes[0].set_ylabel('Deflection', fontsize=40)

axes[1].set_xlabel('Time [s]', fontsize=40)
axes[1].set_ylabel('Velocity', fontsize=40)

axes[0].tick_params(axis='both', which='major', labelsize=30)
axes[1].tick_params(axis='both', which='major', labelsize=30)

fig.tight_layout()
plt.savefig('..\\Documentation\\src\\images\\time_def_vel.eps', format='eps', dpi=1200)
plt.show()

# %%
nrows = 2
ncols = 1
fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(ncols*14, nrows*7))

#axes.plot(data[::steps,1], data[::steps,2], color='grey')
axes[0].scatter(data_small[::steps,1], data_small[::steps,2], color='red')
axes[1].scatter(data_big[::steps,1], data_big[::steps,2], color='red')

axes[0].scatter(data_small[-1,1], data_small[-1,2], color='green', marker='x', s=2000, linewidth=5)
axes[0].scatter(data_small[0,1], data_small[0,2], color='blue', marker='x', s=2000, linewidth=5)
axes[1].scatter(data_big[-1,1], data_big[-1,2], color='green', marker='x', s=2000, linewidth=5)
axes[1].scatter(data_big[0,1], data_big[0,2], color='blue', marker='x', s=2000, linewidth=5)

axes[0].set_xlabel('Deflection', fontsize=40)
axes[0].set_ylabel('Velocity', fontsize=40)
axes[1].set_xlabel('Deflection', fontsize=40)
axes[1].set_ylabel('Velocity', fontsize=40)

axes[0].tick_params(axis='both', which='major', labelsize=30)
axes[1].tick_params(axis='both', which='major', labelsize=30)

plt.savefig('..\\Documentation\\src\\images\\def_vel_2.eps', format='eps', dpi=1200)
plt.show()

# %%
nrows = 3
ncols = 1
fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(ncols*14, nrows*7))

axes[0].plot(data[::steps,0], data[::steps,3], color='grey')
axes[1].plot(data[::steps,1], data[::steps,3], color='grey')
axes[2].plot(data[::steps,2], data[::steps,3], color='grey')

axes[0].scatter(data[::steps,0], data[::steps,3], color='red')
axes[1].scatter(data[::steps,1], data[::steps,3], color='green')
axes[2].scatter(data[::steps,2], data[::steps,3], color='blue')

axes[0].set_xlabel('Time [s]', fontsize=40)
axes[0].set_ylabel('Energy', fontsize=40)
axes[1].set_xlabel('Deflection', fontsize=40)
axes[1].set_ylabel('Energy', fontsize=40)
axes[2].set_xlabel('Velocity', fontsize=40)
axes[2].set_ylabel('Energy', fontsize=40)

axes[0].tick_params(axis='both', which='major', labelsize=30)
axes[1].tick_params(axis='both', which='major', labelsize=30)
axes[2].tick_params(axis='both', which='major', labelsize=30)

fig.tight_layout()
plt.savefig('..\\Documentation\\src\\images\\energy.eps', format='eps', dpi=1200)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# c:\users\masterdesky\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\backends\backend_agg.py in draw_path(self, gc, path, transform, rgbFace)
#     174             try:
# --> 175                 self._renderer.draw_path(gc, path, transform, rgbFace)
#     176             except OverflowError:
#
# OverflowError: In draw_path: Exceeded cell block limit
#
# During handling of the above exception, another exception occurred:
#
# OverflowError                             Traceback (most recent call last)
# <ipython-input-9-938e40b35daa> in <module>()
#      23
#      24 fig.tight_layout()
# ---> 25 plt.savefig('..\\Documentation\\src\\images\\energy.eps', format='eps', dpi=1200)
#      26 plt.show()
#
# c:\users\masterdesky\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     694     fig = gcf()
#     695     res = fig.savefig(*args, **kwargs)
# --> 696     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     697     return res
#     698
#
# c:\users\masterdesky\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\backend_bases.py in draw_idle(self, *args, **kwargs)
#    2053         if not self._is_idle_drawing:
#    2054             with self._idle_draw_cntx():
# -> 2055                 self.draw(*args, **kwargs)
#    2056
#    2057     def draw_cursor(self, event):
#
# c:\users\masterdesky\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     435             # if toolbar:
#     436             #     toolbar.set_cursor(cursors.WAIT)
# --> 437             self.figure.draw(self.renderer)
#     438             # A GUI class may be need to update a window using this draw, so
#     439             # don't forget to call the superclass.
#
# c:\users\masterdesky\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# c:\users\masterdesky\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1491
#    1492             mimage._draw_list_compositing_images(
# -> 1493                 renderer, self, artists, self.suppressComposite)
#    1494
#    1495             renderer.close_group('figure')
#
# c:\users\masterdesky\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     139     if not_composite or not has_images:
#     140         for a in artists:
# --> 141             a.draw(renderer)
#     142     else:
#     143         # Composite any adjacent images together
#
# c:\users\masterdesky\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# c:\users\masterdesky\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2633             renderer.stop_rasterizing()
#    2634
# -> 2635         mimage._draw_list_compositing_images(renderer, self, artists)
#    2636
#    2637         renderer.close_group('axes')
#
# c:\users\masterdesky\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     139     if not_composite or not has_images:
#     140         for a in artists:
# --> 141             a.draw(renderer)
#     142     else:
#     143         # Composite any adjacent images together
#
# c:\users\masterdesky\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# c:\users\masterdesky\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\lines.py in draw(self, renderer)
#     779
#     780                 gc.set_dashes(self._dashOffset, self._dashSeq)
# --> 781                 renderer.draw_path(gc, tpath, affine.frozen())
#     782                 gc.restore()
#     783
#
# c:\users\masterdesky\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\backends\backend_agg.py in draw_path(self, gc, path, transform, rgbFace)
#     175                 self._renderer.draw_path(gc, path, transform, rgbFace)
#     176             except OverflowError:
# --> 177                 raise OverflowError("Exceeded cell block limit (set "
#     178                                     "'agg.path.chunksize' rcparam)")
#     179
#
# OverflowError: Exceeded cell block limit (set 'agg.path.chunksize' rcparam)
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# c:\users\masterdesky\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\backends\backend_agg.py in draw_path(self, gc, path, transform, rgbFace)
#     174             try:
# --> 175                 self._renderer.draw_path(gc, path, transform, rgbFace)
#     176             except OverflowError:
#
# OverflowError: In draw_path: Exceeded cell block limit
#
# During handling of the above exception, another exception occurred:
#
# OverflowError                             Traceback (most recent call last)
# c:\users\masterdesky\appdata\local\programs\python\python37-32\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# c:\users\masterdesky\appdata\local\programs\python\python37-32\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     239
#     240     if 'png' in formats:
# --> 241         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     242     if 'retina' in formats or 'png2x' in formats:
#     243         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# c:\users\masterdesky\appdata\local\programs\python\python37-32\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     123
#     124     bytes_io = BytesIO()
# --> 125     fig.canvas.print_figure(bytes_io, **kw)
#     126     data = bytes_io.getvalue()
#     127     if fmt == 'svg':
#
# c:\users\masterdesky\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2210                     orientation=orientation,
#    2211                     dryrun=True,
# -> 2212                     **kwargs)
#    2213                 renderer = self.figure._cachedRenderer
#    2214                 bbox_inches = self.figure.get_tightbbox(renderer)
#
# c:\users\masterdesky\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     515
#     516     def print_png(self, filename_or_obj, *args, **kwargs):
# --> 517         FigureCanvasAgg.draw(self)
#     518         renderer = self.get_renderer()
#     519         original_dpi = renderer.dpi
#
# c:\users\masterdesky\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     435             # if toolbar:
#     436             #     toolbar.set_cursor(cursors.WAIT)
# --> 437             self.figure.draw(self.renderer)
#     438             # A GUI class may be need to update a window using this draw, so
#     439             # don't forget to call the superclass.
#
# c:\users\masterdesky\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# c:\users\masterdesky\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1488
#    1489             if self.frameon:
# -> 1490                 self.patch.draw(renderer)
#    1491
#    1492             mimage._draw_list_compositing_images(
#
# c:\users\masterdesky\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# c:\users\masterdesky\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\patches.py in draw(self, renderer)
#     556             renderer = PathEffectRenderer(self.get_path_effects(), renderer)
#     557
# --> 558         renderer.draw_path(gc, tpath, affine, rgbFace)
#     559
#     560         gc.restore()
#
# c:\users\masterdesky\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\backends\backend_agg.py in draw_path(self, gc, path, transform, rgbFace)
#     175                 self._renderer.draw_path(gc, path, transform, rgbFace)
#     176             except OverflowError:
# --> 177                 raise OverflowError("Exceeded cell block limit (set "
#     178                                     "'agg.path.chunksize' rcparam)")
#     179
#
# OverflowError: Exceeded cell block limit (set 'agg.path.chunksize' rcparam)
